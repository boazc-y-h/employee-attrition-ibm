# %% [markdown]
# # Installation and Setup

# %%
#installing the library
# %pip install -r "../requirements.txt"
# Out:
# Requirement already satisfied: ipykernel in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from -r ../requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: python-dotenv in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from -r ../requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: sweetviz in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from -r ../requirements.txt (line 3)) (2.3.1)
# Requirement already satisfied: autoviz in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from -r ../requirements.txt (line 4)) (0.1.902)
# Requirement already satisfied: imbalanced-learn in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from -r ../requirements.txt (line 5)) (0.12.4)
# Requirement already satisfied: numpy==1.23.4 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from -r ../requirements.txt (line 6)) (1.23.4)
# Requirement already satisfied: h2o in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from -r ../requirements.txt (line 7)) (3.46.0.6)
# Requirement already satisfied: fairlearn in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from -r ../requirements.txt (line 8)) (0.9.0)
# Requirement already satisfied: comm>=0.1.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (9.0.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (24.2)
# Requirement already satisfied: psutil in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (26.3.0)
# Requirement already satisfied: tornado>=6.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipykernel->-r ../requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from sweetviz->-r ../requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: matplotlib>=3.1.3 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from sweetviz->-r ../requirements.txt (line 3)) (3.7.4)
# Requirement already satisfied: tqdm>=4.43.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from sweetviz->-r ../requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: scipy>=1.3.2 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from sweetviz->-r ../requirements.txt (line 3)) (1.11.4)
# Requirement already satisfied: jinja2>=2.11.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from sweetviz->-r ../requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: importlib-resources>=1.2.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from sweetviz->-r ../requirements.txt (line 3)) (6.5.2)
# Requirement already satisfied: emoji in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (2.14.1)
# Requirement already satisfied: fsspec>=0.8.3 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: holoviews<=1.14.9 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (1.14.9)
# Requirement already satisfied: hvplot~=0.7.3 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (0.7.3)
# Requirement already satisfied: nltk in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (3.9.1)
# Requirement already satisfied: pandas-dq>=1.29 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (1.29)
# Requirement already satisfied: panel~=0.14.4 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (0.14.4)
# Requirement already satisfied: param==1.13.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (1.13.0)
# Requirement already satisfied: pyamg in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: scikit-learn in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: seaborn<=0.12.2 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (0.12.2)
# Requirement already satisfied: statsmodels in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (0.14.4)
# Requirement already satisfied: textblob in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (0.19.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: wordcloud in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (1.9.4)
# Requirement already satisfied: xgboost<1.7,>=0.82 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (1.6.2)
# Requirement already satisfied: xlrd in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from autoviz->-r ../requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: joblib>=1.1.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from imbalanced-learn->-r ../requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from imbalanced-learn->-r ../requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: requests in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from h2o->-r ../requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: tabulate in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from h2o->-r ../requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from holoviews<=1.14.9->autoviz->-r ../requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: colorcet in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from holoviews<=1.14.9->autoviz->-r ../requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: bokeh>=1.0.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from hvplot~=0.7.3->autoviz->-r ../requirements.txt (line 4)) (2.4.3)
# Requirement already satisfied: colorama in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: decorator in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: stack_data in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from jinja2>=2.11.1->sweetviz->-r ../requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements.txt (line 1)) (4.3.6)
# Requirement already satisfied: pywin32>=300 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements.txt (line 1)) (309)
# Requirement already satisfied: contourpy>=1.0.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz->-r ../requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz->-r ../requirements.txt (line 3)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz->-r ../requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz->-r ../requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from matplotlib>=3.1.3->sweetviz->-r ../requirements.txt (line 3)) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz->-r ../requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: markdown in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from panel~=0.14.4->autoviz->-r ../requirements.txt (line 4)) (3.7)
# Requirement already satisfied: pyct>=0.4.4 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from panel~=0.14.4->autoviz->-r ../requirements.txt (line 4)) (0.5.0)
# Requirement already satisfied: bleach in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from panel~=0.14.4->autoviz->-r ../requirements.txt (line 4)) (6.2.0)
# Requirement already satisfied: setuptools>=42 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from panel~=0.14.4->autoviz->-r ../requirements.txt (line 4)) (65.5.0)
# Requirement already satisfied: click in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from nltk->autoviz->-r ../requirements.txt (line 4)) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from nltk->autoviz->-r ../requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from requests->h2o->-r ../requirements.txt (line 7)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from requests->h2o->-r ../requirements.txt (line 7)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from requests->h2o->-r ../requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from requests->h2o->-r ../requirements.txt (line 7)) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.6 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from statsmodels->autoviz->-r ../requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: PyYAML>=3.10 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from bokeh>=1.0.0->hvplot~=0.7.3->autoviz->-r ../requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: wcwidth in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: six>=1.5 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: webencodings in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from bleach->panel~=0.14.4->autoviz->-r ../requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: executing>=1.2.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pure-eval in d:\onedrive\repos\demo-project\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 1)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import h2o
import fairlearn
import pandas as pd
from fairlearn.metrics import MetricFrame, selection_rate, true_positive_rate, true_negative_rate, false_positive_rate, false_negative_rate
from sklearn.metrics import accuracy_score, balanced_accuracy_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Start the H2O cluster (locally)
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# Warning: Your H2O cluster version is (4 months and 16 days) old.  There may be a newer version available.
# Please download and install the latest version from: https://h2o-release.s3.amazonaws.com/h2o/latest_stable.html
# --------------------------  -----------------------------
# H2O_cluster_uptime:         2 hours 7 mins
# H2O_cluster_timezone:       Asia/Kuala_Lumpur
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.6
# H2O_cluster_version_age:    4 months and 16 days
# H2O_cluster_name:           H2O_from_python_user_yv3pf0
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    1.581 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.11.9 final
# --------------------------  -----------------------------

# %% [markdown]
# # Model Interpretation

# %%
model_path = "../models/oversampling/2025-03-17_20-56-34/cv/StackedEnsemble_BestOfFamily_1_AutoML_1_20250317_191731"
best_model = h2o.upload_model(model_path)

# Upload test data
test = h2o.import_file("../data/processed/test_set.csv")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
# Display base model contribution
best_model.metalearner().varimp_plot()

# %%
varimp_df = best_model.metalearner().varimp(use_pandas=True)  # Get variable importance for metalearner
dominant_model_id = varimp_df.iloc[0, 0]  # The model with the highest importance

# Retrieve the dominant base model
dominant_model = h2o.get_model(dominant_model_id)
dominant_model.varimp_plot()

# %%
dominant_model.explain(test, include_explanations="shap_summary")
# Not supported for stacked ensembles
# Out:
# # SHAP Summary
# > SHAP summary plot shows the contribution of the features for each instance (row of data). The sum of the feature contributions and the bias term is equal to the raw prediction of the model, i.e., prediction before applying inverse link function.
# # SHAP Summary
# > SHAP summary plot shows the contribution of the features for each instance (row of data). The sum of the feature contributions and the bias term is equal to the raw prediction of the model, i.e., prediction before applying inverse link function.

# %% [markdown]
# # Preprocessing Predictions and Test Data

# %%
test_decode = test.as_data_frame()
test_decode['Gender'] = test_decode['Gender'].apply(lambda x: 'Male' if x == 0 else 'Female')
test_decode['OverTime'] = test_decode['OverTime'].apply(lambda x: "Yes" if x == 1 else 'No')
# Out:
# d:\OneDrive\Repos\demo-project\.venv\Lib\site-packages\h2o\frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"

# %%
variable_ori_names = ["BusinessTravel", "Department", "EducationField", "JobRole", "MaritalStatus"]

for variable_ori_name in variable_ori_names:
    # Ensure only one-hot encoded columns are used
    one_hot_columns = [col for col in test_decode.columns if variable_ori_name+"_" in col]

    # Apply idxmax only to these columns
    test_decode[variable_ori_name] = test_decode[one_hot_columns].idxmax(axis=1).str.replace(variable_ori_name+"_", "")

    # Drop the original one-hot columns
    test_decode.drop(columns=one_hot_columns, inplace=True)

test_decode
# Out:
#           Age  DailyRate  DistanceFromHome  Education  \
# 0   -1.195770   1.374230          1.949889   0.085020
# 1   -0.210589  -0.065638         -1.010565   1.061426
# 2   -0.210589  -0.298595          1.086423   1.061426
# 3   -0.867377  -0.340725          0.716366   0.085020
# 4    0.555663  -1.490637         -1.010565   1.061426
# ..        ...        ...               ...        ...
# 436 -0.867377  -0.526595         -0.640509   0.085020
# 437  1.431380  -0.013595         -0.640509  -1.867790
# 438 -0.648447  -1.371681         -0.393804   1.061426
# 439 -0.210589   0.197057         -0.763861   1.061426
# 440  0.665128  -0.942942         -1.010565   0.085020
#
#      EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                  -1.575150    Male   -0.880062       -2.431178 -0.961159
# 1                   0.254538    Male   -1.667098       -1.025818 -0.057768
# 2                  -0.660306    Male    0.251303        0.379543 -0.057768
# 3                   0.254538    Male   -0.289785        0.379543 -0.961159
# 4                  -0.660306  Female    1.431858        0.379543 -0.961159
# ..                       ...     ...         ...             ...       ...
# 436                 1.169383  Female    1.235098       -1.025818 -0.961159
# 437                -1.575150    Male    1.481047        0.379543  2.652406
# 438                -0.660306    Male    0.497252       -2.431178 -0.057768
# 439                 1.169383    Male    1.284288        0.379543  0.845624
# 440                 1.169383  Female   -1.617909        0.379543 -0.057768
#
#      JobSatisfaction  ...  ManagementStabilityRatio  JobLevelSalaryRatio  \
# 0           0.246116  ...                  1.000000            -0.745834
# 1          -1.567373  ...                  0.533333            -0.910372
# 2          -1.567373  ...                  0.800000             0.044914
# 3           1.152861  ...                  0.833333            -0.674861
# 4          -1.567373  ...                  0.400000            -0.318491
# ..               ...  ...                       ...                  ...
# 436        -1.567373  ...                  0.000000            -1.023682
# 437        -0.660628  ...                  0.600000            -0.010487
# 438         0.246116  ...                  1.000000             0.512231
# 439         1.152861  ...                  0.800000            -0.854876
# 440         1.152861  ...                  0.400000             0.045678
#
#      DepartmentSalaryRatio EducationReturnRatio  Attrition     BusinessTravel  \
# 0                -0.870527            -0.895721          1      Travel_Rarely
# 1                -0.521519            -0.509781          0      Travel_Rarely
# 2                -0.275454            -0.257156          0      Travel_Rarely
# 3                -0.860268            -0.885755          0      Travel_Rarely
# 4                -0.808756            -0.860907          0      Travel_Rarely
# ..                     ...                  ...        ...                ...
# 436              -0.910689            -0.934737          0      Travel_Rarely
# 437               2.807588             3.308324          0      Travel_Rarely
# 438              -0.155081            -0.133574          1      Travel_Rarely
# 439               0.170183             0.200360          0      Travel_Rarely
# 440              -0.156993            -0.202556          0  Travel_Frequently
#
#                  Department    EducationField                    JobRole  \
# 0    Research & Development     Life Sciences      Laboratory Technician
# 1                     Sales         Marketing            Sales Executive
# 2                     Sales           Medical            Sales Executive
# 3    Research & Development     Life Sciences         Research Scientist
# 4    Research & Development     Life Sciences      Laboratory Technician
# ..                      ...               ...                        ...
# 436  Research & Development  Technical Degree         Research Scientist
# 437  Research & Development     Life Sciences          Research Director
# 438                   Sales     Life Sciences            Sales Executive
# 439                   Sales     Life Sciences            Sales Executive
# 440  Research & Development     Life Sciences  Healthcare Representative
#
#      MaritalStatus
# 0           Single
# 1           Single
# 2          Married
# 3           Single
# 4         Divorced
# ..             ...
# 436       Divorced
# 437       Divorced
# 438        Married
# 439       Divorced
# 440        Married
#
# [441 rows x 37 columns]

# %%
# Make predictions # Note take h2o takes the CV threshold
predictions = best_model.predict(test)

# Convert H2OFrame to Pandas
predictions = predictions.as_data_frame()

#Reset index
predictions.reset_index(drop=True)
test_decode.reset_index(drop=True)

# Merge predictions with test data
merged_df = pd.concat([predictions,test_decode], axis=1)

# Print df
merged_df
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# d:\OneDrive\Repos\demo-project\.venv\Lib\site-packages\h2o\frame.py:1983: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
#      predict        p0            p1       Age  DailyRate  DistanceFromHome  \
# 0          1  0.172978  8.270225e-01 -1.195770   1.374230          1.949889
# 1          0  0.999844  1.562022e-04 -0.210589  -0.065638         -1.010565
# 2          0  0.999896  1.038397e-04 -0.210589  -0.298595          1.086423
# 3          0  0.998365  1.635442e-03 -0.867377  -0.340725          0.716366
# 4          0  0.999937  6.294739e-05  0.555663  -1.490637         -1.010565
# ..       ...       ...           ...       ...        ...               ...
# 436        0  0.965725  3.427474e-02 -0.867377  -0.526595         -0.640509
# 437        0  0.999991  8.775803e-06  1.431380  -0.013595         -0.640509
# 438        0  0.864637  1.353629e-01 -0.648447  -1.371681         -0.393804
# 439        0  1.000000  6.901734e-09 -0.210589   0.197057         -0.763861
# 440        0  0.999996  3.534856e-06  0.665128  -0.942942         -1.010565
#
#      Education  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0     0.085020                -1.575150    Male   -0.880062  ...
# 1     1.061426                 0.254538    Male   -1.667098  ...
# 2     1.061426                -0.660306    Male    0.251303  ...
# 3     0.085020                 0.254538    Male   -0.289785  ...
# 4     1.061426                -0.660306  Female    1.431858  ...
# ..         ...                      ...     ...         ...  ...
# 436   0.085020                 1.169383  Female    1.235098  ...
# 437  -1.867790                -1.575150    Male    1.481047  ...
# 438   1.061426                -0.660306    Male    0.497252  ...
# 439   1.061426                 1.169383    Male    1.284288  ...
# 440   0.085020                 1.169383  Female   -1.617909  ...
#
#      ManagementStabilityRatio  JobLevelSalaryRatio  DepartmentSalaryRatio  \
# 0                    1.000000            -0.745834              -0.870527
# 1                    0.533333            -0.910372              -0.521519
# 2                    0.800000             0.044914              -0.275454
# 3                    0.833333            -0.674861              -0.860268
# 4                    0.400000            -0.318491              -0.808756
# ..                        ...                  ...                    ...
# 436                  0.000000            -1.023682              -0.910689
# 437                  0.600000            -0.010487               2.807588
# 438                  1.000000             0.512231              -0.155081
# 439                  0.800000            -0.854876               0.170183
# 440                  0.400000             0.045678              -0.156993
#
#      EducationReturnRatio  Attrition     BusinessTravel  \
# 0               -0.895721          1      Travel_Rarely
# 1               -0.509781          0      Travel_Rarely
# 2               -0.257156          0      Travel_Rarely
# 3               -0.885755          0      Travel_Rarely
# 4               -0.860907          0      Travel_Rarely
# ..                    ...        ...                ...
# 436             -0.934737          0      Travel_Rarely
# 437              3.308324          0      Travel_Rarely
# 438             -0.133574          1      Travel_Rarely
# 439              0.200360          0      Travel_Rarely
# 440             -0.202556          0  Travel_Frequently
#
#                  Department    EducationField                    JobRole  \
# 0    Research & Development     Life Sciences      Laboratory Technician
# 1                     Sales         Marketing            Sales Executive
# 2                     Sales           Medical            Sales Executive
# 3    Research & Development     Life Sciences         Research Scientist
# 4    Research & Development     Life Sciences      Laboratory Technician
# ..                      ...               ...                        ...
# 436  Research & Development  Technical Degree         Research Scientist
# 437  Research & Development     Life Sciences          Research Director
# 438                   Sales     Life Sciences            Sales Executive
# 439                   Sales     Life Sciences            Sales Executive
# 440  Research & Development     Life Sciences  Healthcare Representative
#
#      MaritalStatus
# 0           Single
# 1           Single
# 2          Married
# 3           Single
# 4         Divorced
# ..             ...
# 436       Divorced
# 437       Divorced
# 438        Married
# 439       Divorced
# 440        Married
#
# [441 rows x 40 columns]

# %% [markdown]
# # Fairness Evaluation

# %%
# Create function for fairness evaluation
def fairness_eval(attr, merged_df=merged_df):
    
    # Add predictions and sensitive attributes
    sensitive_attribute = merged_df[attr]  # Replace with your sensitive attribute
    true_labels = merged_df["Attrition"]

    # Evaluate fairness metrics
    metrics = MetricFrame(
        metrics={
            "accuracy": accuracy_score,
            "selection_rate": selection_rate,
            "true_positive_rate": true_positive_rate,
            "true_negative_rate": true_negative_rate,
            "false_positive_rate": false_positive_rate,
            "false_negative_rate": false_negative_rate,
            "balanced_accuracy": balanced_accuracy_score,
        },
        y_true=true_labels,
        y_pred=merged_df["predict"],
        sensitive_features=sensitive_attribute
    )

    print(metrics.by_group)

    metrics_to_report = ['selection_rate','true_positive_rate','false_positive_rate']

    # Plotting the bar plots and getting the bar containers
    axes = metrics.by_group[metrics_to_report].plot.bar(
        subplots=True, layout=[1, 3], figsize=[12, 6], legend=None, rot=90
    )

    # Annotating the values on the bars
    for ax in axes.flatten():
        # Loop over all the bars in the plot
        for p in ax.patches:
            # Annotate the bar
            ax.annotate(
                f'{p.get_height():.2f}',  # Display the value with two decimal places
                (p.get_x() + p.get_width() / 2, p.get_height()),  # Position: centered above the bar
                textcoords="offset points",  # Use offset points for position adjustment
                xytext=(0, 5),  # Slight vertical offset
                ha='center',  # Center the text horizontally
                fontsize=10  # Font size
            )

    plt.show()

# %%
sensitive_attributes = ['Gender', 'OverTime'] + variable_ori_names

for sensitive_attribute in sensitive_attributes:
    print(sensitive_attribute+"\n")
    fairness_eval(sensitive_attribute)
    print("\n")
# Out:
# Gender
#
#         accuracy  selection_rate  true_positive_rate  true_negative_rate  \
# Gender
# Female  0.905028        0.005587            0.055556                 1.0
# Male    0.874046        0.022901            0.153846                 1.0
#
#         false_positive_rate  false_negative_rate  balanced_accuracy
# Gender
# Female                  0.0             0.944444           0.527778
# Male                    0.0             0.846154           0.576923
# OverTime
#
#           accuracy  selection_rate  true_positive_rate  true_negative_rate  \
# OverTime
# No        0.929878        0.006098             0.08000                 1.0
# Yes       0.761062        0.044248             0.15625                 1.0
#
#           false_positive_rate  false_negative_rate  balanced_accuracy
# OverTime
# No                        0.0              0.92000           0.540000
# Yes                       0.0              0.84375           0.578125
# BusinessTravel
#
#                    accuracy  selection_rate  true_positive_rate  \
# BusinessTravel
# Non-Travel         0.959184        0.000000            0.000000
# Travel_Frequently  0.825000        0.050000            0.222222
# Travel_Rarely      0.891026        0.009615            0.081081
#
#                    true_negative_rate  false_positive_rate  \
# BusinessTravel
# Non-Travel                        1.0                  0.0
# Travel_Frequently                 1.0                  0.0
# Travel_Rarely                     1.0                  0.0
#
#                    false_negative_rate  balanced_accuracy
# BusinessTravel
# Non-Travel                    1.000000           0.500000
# Travel_Frequently             0.777778           0.611111
# Travel_Rarely                 0.918919           0.540541
# Department
#
#                         accuracy  selection_rate  true_positive_rate  \
# Department
# Human Resources         0.866667        0.000000            0.000000
# Research & Development  0.914676        0.010239            0.107143
# Sales                   0.827068        0.030075            0.148148
#
#                         true_negative_rate  false_positive_rate  \
# Department
# Human Resources                        1.0                  0.0
# Research & Development                 1.0                  0.0
# Sales                                  1.0                  0.0
#
#                         false_negative_rate  balanced_accuracy
# Department
# Human Resources                    1.000000           0.500000
# Research & Development             0.892857           0.553571
# Sales                              0.851852           0.574074
# EducationField
#
#                   accuracy  selection_rate  true_positive_rate  \
# EducationField
# Human Resources   1.000000        0.000000            0.000000
# Life Sciences     0.898876        0.022472            0.181818
# Marketing         0.839286        0.035714            0.181818
# Medical           0.889706        0.007353            0.062500
# Other             1.000000        0.000000            0.000000
# Technical Degree  0.822222        0.000000            0.000000
#
#                   true_negative_rate  false_positive_rate  \
# EducationField
# Human Resources                  1.0                  0.0
# Life Sciences                    1.0                  0.0
# Marketing                        1.0                  0.0
# Medical                          1.0                  0.0
# Other                            1.0                  0.0
# Technical Degree                 1.0                  0.0
#
#                   false_negative_rate  balanced_accuracy
# EducationField
# Human Resources              0.000000           1.000000
# Life Sciences                0.818182           0.590909
# Marketing                    0.818182           0.590909
# Medical                      0.937500           0.531250
# Other                        0.000000           1.000000
# Technical Degree             1.000000           0.500000
# d:\OneDrive\Repos\demo-project\.venv\Lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# d:\OneDrive\Repos\demo-project\.venv\Lib\site-packages\sklearn\metrics\_classification.py:386: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# JobRole
#
#                            accuracy  selection_rate  true_positive_rate  \
# JobRole
# Healthcare Representative  0.979167        0.000000            0.000000
# Human Resources            0.857143        0.000000            0.000000
# Laboratory Technician      0.845070        0.014085            0.083333
# Manager                    0.972973        0.000000            0.000000
# Manufacturing Director     0.957447        0.000000            0.000000
# Research Director          0.960000        0.000000            0.000000
# Research Scientist         0.891566        0.024096            0.181818
# Sales Executive            0.802198        0.000000            0.000000
# Sales Representative       0.800000        0.160000            0.444444
#
#                            true_negative_rate  false_positive_rate  \
# JobRole
# Healthcare Representative                 1.0                  0.0
# Human Resources                           1.0                  0.0
# Laboratory Technician                     1.0                  0.0
# Manager                                   1.0                  0.0
# Manufacturing Director                    1.0                  0.0
# Research Director                         1.0                  0.0
# Research Scientist                        1.0                  0.0
# Sales Executive                           1.0                  0.0
# Sales Representative                      1.0                  0.0
#
#                            false_negative_rate  balanced_accuracy
# JobRole
# Healthcare Representative             1.000000           0.500000
# Human Resources                       1.000000           0.500000
# Laboratory Technician                 0.916667           0.541667
# Manager                               1.000000           0.500000
# Manufacturing Director                1.000000           0.500000
# Research Director                     1.000000           0.500000
# Research Scientist                    0.818182           0.590909
# Sales Executive                       1.000000           0.500000
# Sales Representative                  0.555556           0.722222
# MaritalStatus
#
#                accuracy  selection_rate  true_positive_rate  \
# MaritalStatus
# Divorced       0.946237        0.000000            0.000000
# Married        0.912195        0.004878            0.052632
# Single         0.811189        0.041958            0.181818
#
#                true_negative_rate  false_positive_rate  false_negative_rate  \
# MaritalStatus
# Divorced                      1.0                  0.0             1.000000
# Married                       1.0                  0.0             0.947368
# Single                        1.0                  0.0             0.818182
#
#                balanced_accuracy
# MaritalStatus
# Divorced                0.500000
# Married                 0.526316
# Single                  0.590909
